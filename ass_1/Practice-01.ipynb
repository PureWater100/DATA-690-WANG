# %% [markdown]
# ### Control Flow

# %% [markdown]
# ### Ternary expressions

# %%
x = 5
'Non-negative' if x >= 0 else 'Negative'
# Out:
# 'Non-negative'

# %% [markdown]
# ### Range

# %%
list(range(0, 20, 2))
list(range(5, 0, -1))
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ### Pass

# %%
if x < 0:
    print('negative!')
elif x == 0:
    # TODO: put something smart here
    pass
else:
    print('positive!')
# Out:
# positive!

# %% [markdown]
# ### while loops

# %%
x = 256
total = 0
while x > 0:
    if total > 500:
        break
    total += x
    x = x // 2

# %% [markdown]
# ### for loops

# %%
for i in range(4):
    for j in range(4):
        if j > i:
            break
        print((i, j))
# Out:
# (0, 0)
# (1, 0)
# (1, 1)
# (2, 0)
# (2, 1)
# (2, 2)
# (3, 0)
# (3, 1)
# (3, 2)
# (3, 3)

# %% [markdown]
# ### if, elif, and else

# %%
a = 5; b = 7
c = 8; d = 4
if a < b or c > d:
    print('Made it')
# Out:
# Made it

# %% [markdown]
# ### Scalar Types

# %% [markdown]
# ### Dates and Times

# %%
from datetime import datetime, date, time
dt = datetime(2011, 10, 29, 20, 30, 21)
dt.day
dt.minute
# Out:
# 30

# %% [markdown]
# ### Type Casting

# %%
s = '3.14159'
fval = float(s)
type(fval)
int(fval)
bool(fval)
bool(0)
# Out:
# False

# %% [markdown]
# ### Booleans

# %%
True and True
False or True
# Out:
# True

# %% [markdown]
# ### Bytes and unicode

# %%
val = "español"
val

val_utf8 = val.encode('utf-8')
val_utf8
type(val_utf8)
# Out:
# bytes

# %% [markdown]
# ### Strings

# %%
a = 'this is the first half '
b = 'and this is the second half'
a + b
# Out:
# 'this is the first half and this is the second half'

# %% [markdown]
# ### Mutable and immutable objects

# %%
a_list = ['foo', 2, [4, 5]]
a_list[2] = (3, 4)
a_list

# tuples are immutable 
# a_tuple = (3, 5, (4, 5))
# a_tuple[1] = 'four'
# Out:
# ['foo', 2, (3, 4)]

# %% [markdown]
# ### Binary operators and comparisons

# %%
5-7
# Out:
# -2

# %%
12 + 21.5
# Out:
# 33.5

# %%
5 <= 2
# Out:
# False

# %% [markdown]
# ### Duck typing

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError: # not iterable
        return False

# %% [markdown]
# ### Dynamic references and strong types

# %%
a = 5
type(a)
a = 'foo'
type(a)
# Out:
# str

# %% [markdown]
# ### Altering the internals of a mutatble argument

# %%
def append_element(some_list, element):
    some_list.append(element)

data = [1,2,3]
append_element(data,4)
data
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### Introspection

# %%
#introspection
b = [1, 2, 3] 
b?

# %% [markdown]
# ### Typing just a varialbe into IPython gives a string representation of the object

# %%
import numpy as np 
data = {i : np.random.randn() for i in range(7)}
data
# Out:
# {0: -0.08855506402170102,
#  1: 0.4626222880742615,
#  2: -1.0080625756615804,
#  3: -1.4027053954228634,
#  4: -0.13689431649300587,
#  5: 1.671763864892714,
#  6: 0.6638627786709557}

# %% [markdown]
# ### Program: prints out "Hello world"

# %%
print('Hello world')
# Out:
# Hello world
